# %%
import random 
import numpy as np

#Main lists

game_on=True
game_off=False

boxes=0

mine_list=[]
flag_list=[]

#Welcome Message and choose level 
    ## no me sale al inicio
print('Welcome to Minesweeper Ironhack 2022! \nEnter your board size: \n8 for 8x8 board or \n16 for 16x16 board')

#Define board size

board_size=int(input('Enter the board size: '))

        #numpy?
        #board= [['[ ]' for i in range(board_size)] for j in range(board_size)]

#Define mines

n=int((board_size**2)*0.25)
    
r1=random.sample(range(board_size**2), n)
r2=random.sample(range(board_size**2), n)
    
for i in range (n):
    mine_list.append((r1[i] , r2[i]))
    
#define numbers around mines

    #mappear las ocho casillas aledañas para definir el numero de minas

while(game_on):
    
#choose your coordinates

    #x_coor=input('Enter coordinate in x: '))
    #y_coor=input('Enter coordinate in y: '))

#choose wheter is a flag or a mine
    
    #move=input('Is it a mine or a flag? Choose wisely... '))
    
    #TURN -- MINE or SAFE
    
         #if ((x_coor,y_coor) in mine_list):
            #print ('BAAAANG!!! \n You lost...)
            #run=False
        
        #else:
        #if (board[row,col] == '[ ]'):
            #board[row,col]= show number
        
        
        #destapar casillas******
        
                #continue
                
    #FLAG
        #if move == 'flag':
            #flag_list.append((x_coor,y_coor))
            #continue
            #boxes=0
            
            
    #WIN OR LOOSE
    
        #if (points == board_size**2-n):
            #print ('You won!')
            #game_on=False
    
    #NEW GAME
    
        #new_game=int(input('Wanna play again?: 1 for yes, 0 for no '))

            #if game_on == False_
                #if new_game == 1:
                #return True
            #else:
                #return False
